# %% [markdown]
# # Train a Convolutional Neural Network to find collapsing roofs

# %% [markdown]
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %% [markdown]
# ## Load necessary libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 64 #should be same size or smaller than number of images, should not be bigger
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# Add my own data
# Import packages to use google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Add file paths to photos

# %%
root_dir
# Out:
# '/content/gdrive/My Drive/'

# %%
import os
os.chdir(root_dir+'taggedRoofs')
os.getcwd()
# Out:
# '/content/gdrive/My Drive/taggedRoofs'

# %%
fnames = get_image_files(os.getcwd())
fnames[:7]
# Out:
# [PosixPath('/content/gdrive/My Drive/taggedRoofs/b_325.tif'),
#  PosixPath('/content/gdrive/My Drive/taggedRoofs/b_3.tif'),
#  PosixPath('/content/gdrive/My Drive/taggedRoofs/b_2.tif'),
#  PosixPath('/content/gdrive/My Drive/taggedRoofs/b_7.tif'),
#  PosixPath('/content/gdrive/My Drive/taggedRoofs/b_4.tif'),
#  PosixPath('/content/gdrive/My Drive/taggedRoofs/b_1.tif'),
#  PosixPath('/content/gdrive/My Drive/taggedRoofs/b_5.tif')]

# %%
len(fnames)
# Out:
# 632

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# photos are from the USGS earth explorer website. the year 2014 was choosen.

# %%
path = pathlib.Path(os.getcwd())
path
# Out:
# PosixPath('/content/gdrive/My Drive/taggedRoofs')

# %%
doc(pathlib.Path)

# %%
#path.ls()

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
path_anno = path/'annotations'
path_img = root_dir+'taggedRoofs'

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, labels are stored in the filenames themselves. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %%
len(fnames)
# Out:
# 623

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.tif$'

import re
re.search(pat, '/content/gdrive/My Drive/taggedRoofs/b_527.tif').group(0)
# Out:
# '/b_527.tif'

# %%
doc(ImageDataBunch)

# %%
data = ImageDataBunch.from_name_re(path, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=4, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['b', 'g']
# (2, 2)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.359193</td>
#       <td>1.171162</td>
#       <td>0.515873</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.145300</td>
#       <td>0.677522</td>
#       <td>0.309524</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.974892</td>
#       <td>0.616923</td>
#       <td>0.206349</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.874036</td>
#       <td>0.574919</td>
#       <td>0.206349</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.808936</td>
#       <td>0.595744</td>
#       <td>0.190476</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L163" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><
# ...

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=70)

# %%
interp.most_confused(min_val=2)
# Out:
# [('b', 'g', 14), ('g', 'b', 4)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.372894</td>
#       <td>0.539118</td>
#       <td>0.150794</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='15', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       73.33% [11/15 00:45<00:16]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(20, max_lr=slice(1e-5,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.323950</td>
#       <td>0.348195</td>
#       <td>0.126984</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.264294</td>
#       <td>0.325386</td>
#       <td>0.119048</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.274889</td>
#       <td>0.311148</td>
#       <td>0.111111</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.238456</td>
#       <td>0.302811</td>
#       <td>0.095238</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.223518</td>
#       <td>0.274699</td>
#       <td>0.111111</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.predict??

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=70)

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
data = ImageDataBunch.from_name_re(path, fnames, pat, ds_tfms=get_transforms(),
                                   size=224, bs=bs//2).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       71.43% [5/7 01:09<00:27]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.275847</td>
#       <td>0.585360</td>
#       <td>0.253968</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.000382</td>
#       <td>0.548193</td>
#       <td>0.190476</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.872522</td>
#       <td>0.741908</td>
#       <td>0.214286</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.835709</td>
#       <td>0.792051</td>
#       <td>0.214286</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.822296</td>
#       <td>0.666750</td>
#       <td>0.206349</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1-resnet50')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/7 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.unfreeze()
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.164727</td>
#       <td>0.311083</td>
#       <td>0.119048</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.174097</td>
#       <td>0.369269</td>
#       <td>0.126984</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.140391</td>
#       <td>0.496845</td>
#       <td>0.103175</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.132463</td>
#       <td>0.938366</td>
#       <td>0.174603</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.184418</td>
#       <td>0.365149</td>
#       <td>0.111111</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.save('stage-1-resnet50')

# %% [markdown]
# If it doesn't, you can always go back to your previous model.

# %%
learn.load('stage-1-resnet50');
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/7 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.unfreeze()
learn.fit_one_cycle(40, max_lr=slice(1e-6,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.035729</td>
#       <td>0.514584</td>
#       <td>0.103175</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.018262</td>
#       <td>0.502848</td>
#       <td>0.095238</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.012303</td>
#       <td>0.471333</td>
#       <td>0.087302</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.011653</td>
#       <td>0.465389</td>
#       <td>0.079365</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.015567</td>
#       <td>0.501933</td>
#       <td>0.087302</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=70)

# %%
interp.most_confused(min_val=2)
# Out:
# [('g', 'b', 7), ('b', 'g', 4)]

# %% [markdown]
# ## Other data formats

# %%
path = untar_data(URLs.MNIST_SAMPLE); path
# Out:
# PosixPath('/home/ubuntu/course-v3/nbs/dl1/data/mnist_sample')

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=26)

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit(2)
# Out:
# Total time: 00:23
# epoch  train_loss  valid_loss  accuracy
# 1      0.116117    0.029745    0.991168  (00:12)
# 2      0.056860    0.015974    0.994603  (00:10)

# %%
df = pd.read_csv(path/'labels.csv')
df.head()
# Out:
#                 name  label
# 0   train/3/7463.png      0
# 1  train/3/21102.png      0
# 2  train/3/31559.png      0
# 3  train/3/46882.png      0
# 4  train/3/26209.png      0

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28)

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes
# Out:
# [0, 1]

# %%
data = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
data.classes
# Out:
# [0, 1]

# %%
fn_paths = [path/name for name in df['name']]; fn_paths[:2]
# Out:
# [PosixPath('/home/ubuntu/course-v3/nbs/dl1/data/mnist_sample/train/3/7463.png'),
#  PosixPath('/home/ubuntu/course-v3/nbs/dl1/data/mnist_sample/train/3/21102.png')]

# %%
pat = r"/(\d)/\d+\.png$"
data = ImageDataBunch.from_name_re(path, fn_paths, pat=pat, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']

# %%
data = ImageDataBunch.from_name_func(path, fn_paths, ds_tfms=tfms, size=24,
        label_func = lambda x: '3' if '/3/' in str(x) else '7')
data.classes
# Out:
# ['3', '7']

# %%
labels = [('3' if '/3/' in str(x) else '7') for x in fn_paths]
labels[:5]
# Out:
# ['3', '3', '3', '3', '3']

# %%
data = ImageDataBunch.from_lists(path, fn_paths, labels=labels, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']

# %% [markdown]
# #Rerun Code, simplified

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *
from fastai.metrics import error_rate

bs = 64 #should be same size or smaller than number of images, should not be bigger

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir(root_dir+'taggedRoofs')
os.getcwd()
# Out:
# '/content/gdrive/My Drive/taggedRoofs'

# %%
fnames = get_image_files(os.getcwd())
len(fnames)
# Out:
# 632

# %%
path = pathlib.Path(os.getcwd())
path_anno = path/'annotations'
path_img = root_dir+'taggedRoofs'

import re
np.random.seed(2)
pat = r'/([^/]+)_\d+.tif$'

data = ImageDataBunch.from_name_re(path, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet34, metrics=(error_rate))
learn.model
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
# ...

# %%
learn.fit_one_cycle(20) #number of epochs
learn.save('stage-1') #save model
learn.export()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.217011</td>
#       <td>0.768344</td>
#       <td>0.380952</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.137887</td>
#       <td>0.534899</td>
#       <td>0.269841</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.963932</td>
#       <td>0.496853</td>
#       <td>0.198413</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.871704</td>
#       <td>0.492069</td>
#       <td>0.166667</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.798077</td>
#       <td>0.541579</td>
#       <td>0.190476</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=70)

# %%
help(learn.predict)
# Out:
# Help on method predict in module fastai.basic_train:
#
# predict(item:fastai.core.ItemBase, return_x:bool=False, batch_first:bool=True, with_dropout:bool=False, **kwargs) method of fastai.basic_train.Learner instance
#     Return predicted class, label and probabilities for `item`.

# %%
for i in range(1,20):
  img = data.valid_ds[i][0]
  print(learn.predict(img))
# Out:
# (Category g, tensor(1), tensor([0.0156, 0.9844]))
# (Category b, tensor(0), tensor([1.0000e+00, 9.4488e-09]))
# (Category g, tensor(1), tensor([1.8815e-04, 9.9981e-01]))
# (Category b, tensor(0), tensor([0.9976, 0.0024]))
# (Category g, tensor(1), tensor([2.7548e-05, 9.9997e-01]))
# (Category b, tensor(0), tensor([0.8948, 0.1052]))
# (Category g, tensor(1), tensor([4.1799e-04, 9.9958e-01]))
# (Category b, tensor(0), tensor([9.9995e-01, 5.0182e-05]))
# (Category b, tensor(0), tensor([0.9848, 0.0152]))
# (Category g, tensor(1), tensor([0.0167, 0.9833]))
# (Category g, tensor(1), tensor([0.0016, 0.9984]))
# (Category b, tensor(0), tensor([9.9972e-01, 2.8231e-04]))
# (Category g, tensor(1), tensor([0.0630, 0.9370]))
# (Category g, tensor(1), tensor([0.0067, 0.9933]))
# (Category b, tensor(0), tensor([0.9959, 0.0041]))
# (Category b, tensor(0), tensor([9.9955e-01, 4.5292e-04]))
# (Category g, tensor(1), tensor([2.3440e-04, 9.9977e-01]))
# (Category b, tensor(0), tensor([0.9347, 0.0653]))
# ...

# %%
data.

# %%
img
# Out:
# Image (3, 224, 224)

# %%
os.getcwd()
# Out:
# '/content/gdrive/My Drive/taggedRoofs'

# %%
test1 = ImageImageList.from_folder('/content/gdrive/My Drive/taggedRoofs/TestSet')
#learn.load('stage-1')
#test1
#learner = load_learner(path, test=test)
learner = load_learner(os.getcwd(), test=test1)

# %%
test1
# Out:
# ImageImageList (45 items)
# Image (3, 224, 225),Image (3, 224, 225),Image (3, 225, 225),Image (3, 224, 225),Image (3, 225, 225)
# Path: /content/gdrive/My Drive/taggedRoofs/TestSet

# %%
preds, _ = learner.get_preds(ds_type=DatasetType.Test)

# %%
preds
# Out:
# tensor([[8.1542e-01, 1.8458e-01],
#         [2.8550e-03, 9.9714e-01],
#         [9.9198e-01, 8.0225e-03],
#         [3.3169e-02, 9.6683e-01],
#         [1.3910e-03, 9.9861e-01],
#         [4.3422e-04, 9.9957e-01],
#         [4.0071e-04, 9.9960e-01],
#         [7.3917e-01, 2.6083e-01],
#         [7.7153e-01, 2.2847e-01],
#         [9.3045e-01, 6.9552e-02],
#         [7.4914e-01, 2.5086e-01],
#         [1.3813e-03, 9.9862e-01],
#         [4.0119e-02, 9.5988e-01],
#         [9.5540e-01, 4.4602e-02],
#         [9.9955e-01, 4.5170e-04],
#         [3.7688e-01, 6.2312e-01],
#         [1.2114e-01, 8.7886e-01],
#         [1.5079e-02, 9.8492e-01],
#         [1.2304e-01, 8.7696e-01],
#         [1.7721e-02, 9.8228e-01],
#         [3.8003e-02, 9.6200e-01],
#         [5.8066e-03, 9.9419e-01],
#         [9.4876e-01, 5.1235e-02],
#         [9.5327e-01, 4.6732e-02],
#         [9.8920e-01, 1.0801e-02],
#         [9.9376e-01, 6.2437e-03],
#         [9.9869e-01, 1.3130e-03],
# ...

# %%
test1.items
# Out:
# array([PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/1802-RAYNER-AVE.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/1914-HARLEM-AVE.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/1916-EDMONDSON-AVE.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/323-N-MOUNT-ST.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/248-N-PAYSON-ST.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/222-N-MONROE-ST.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/202-N-GILMOR-ST.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/525-N-PULASKI-ST.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/728-N-GILMOR-ST.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/713-APPLETON-ST.tif'),
#        PosixPath('/content/gdrive/My Drive/taggedRoofs/TestSet/527-N-PULASKI-ST.tif'),
# ...

# %%
learner

# %%
preds
# Out:
# tensor([[8.1542e-01, 1.8458e-01],
#         [2.8550e-03, 9.9714e-01],
#         [9.9198e-01, 8.0225e-03],
#         [3.3169e-02, 9.6683e-01],
#         [1.3910e-03, 9.9861e-01],
#         [4.3422e-04, 9.9957e-01],
#         [4.0071e-04, 9.9960e-01],
#         [7.3917e-01, 2.6083e-01],
#         [7.7153e-01, 2.2847e-01],
#         [9.3045e-01, 6.9552e-02],
#         [7.4914e-01, 2.5086e-01],
#         [1.3813e-03, 9.9862e-01],
#         [4.0119e-02, 9.5988e-01],
#         [9.5540e-01, 4.4602e-02],
#         [9.9955e-01, 4.5170e-04],
#         [3.7688e-01, 6.2312e-01],
#         [1.2114e-01, 8.7886e-01],
#         [1.5079e-02, 9.8492e-01],
#         [1.2304e-01, 8.7696e-01],
#         [1.7721e-02, 9.8228e-01],
#         [3.8003e-02, 9.6200e-01],
#         [5.8066e-03, 9.9419e-01],
#         [9.4876e-01, 5.1235e-02],
#         [9.5327e-01, 4.6732e-02],
#         [9.8920e-01, 1.0801e-02],
#         [9.9376e-01, 6.2437e-03],
#         [9.9869e-01, 1.3130e-03],
# ...

# %%
fullTif = r'/([^/]+)$'

import re
re.search(pat, '/content/gdrive/My Drive/taggedRoofs/b_527.tif').group(0)
# Out:
# '/b_527.tif'

# %%
columns = ["path"]
df = pd.DataFrame(data=test1.items, columns=columns)
df
# Out:
#                                                 path
# 0  /content/gdrive/My Drive/taggedRoofs/TestSet/1...
# 1  /content/gdrive/My Drive/taggedRoofs/TestSet/1...
# 2  /content/gdrive/My Drive/taggedRoofs/TestSet/1...

# %%
df['Address'] = preds
df
# Out:
#                                                 path                           Address
# 0  /content/gdrive/My Drive/taggedRoofs/TestSet/1...  (tensor(0.8154), tensor(0.1846))
# 1  /content/gdrive/My Drive/taggedRoofs/TestSet/1...  (tensor(0.0029), tensor(0.9971))
# 2  /content/gdrive/My Drive/taggedRoofs/TestSet/1...  (tensor(0.9920), tensor(0.0080))

# %%
print(float(preds[0][0]))
float(preds[0][1])
float(preds[1][0])
# Out:
# 0.815414309501648
# 0.002855040365830064

# %%
num_samples = len(preds)
num_classes = 2
df = pd.DataFrame(index=range(num_samples), columns=[str(x) for x in range(num_classes)])
for j in range(num_samples):
  for i in range(num_classes):
    df.iloc[j][i] = float(preds[j][i])
df
# Out:
#               0            1
# 0      0.815418     0.184582
# 1    0.00285505     0.997145
# 2      0.991978   0.00802246
# 3     0.0331691     0.966831
# 4      0.001391     0.998609
# 5    0.00043422     0.999566
# 6   0.000400706     0.999599
# 7      0.739165     0.260835
# 8      0.771535     0.228465
# 9      0.930448    0.0695521
# 10     0.749136     0.250864
# 11    0.0013813     0.998619
# 12    0.0401192     0.959881
# 13     0.955398    0.0446018
# 14     0.999548  0.000451703
# 15     0.376885     0.623115
# 16     0.121138     0.878862
# 17    0.0150788     0.984921
# 18     0.123037     0.876963
# 19    0.0177209     0.982279
# 20    0.0380035     0.961997
# 21   0.00580665     0.994193
# 22     0.948765    0.0512354
# 23     0.953268    0.0467324
# 24     0.989199     0.010801
# 25     0.993756   0.00624373
# 26     0.998687   0.00131299
# 27     0.882973     0.117027
# 28     0.142913     0.857087
# 29     0.977982    0.0220183
# 30     0.978272     0.021728
# ...

# %%
df['filePath'] = test1.items
df
# Out:
#               0            1                                           filePath
# 0      0.815418     0.184582  /content/gdrive/My Drive/taggedRoofs/TestSet/1...
# 1    0.00285505     0.997145  /content/gdrive/My Drive/taggedRoofs/TestSet/1...
# 2      0.991978   0.00802246  /content/gdrive/My Drive/taggedRoofs/TestSet/1...
# 3     0.0331691     0.966831  /content/gdrive/My Drive/taggedRoofs/TestSet/3...
# 4      0.001391     0.998609  /content/gdrive/My Drive/taggedRoofs/TestSet/2...
# 5    0.00043422     0.999566  /content/gdrive/My Drive/taggedRoofs/TestSet/2...
# 6   0.000400706     0.999599  /content/gdrive/My Drive/taggedRoofs/TestSet/2...
# 7      0.739165     0.260835  /content/gdrive/My Drive/taggedRoofs/TestSet/5...
# 8      0.771535     0.228465  /content/gdrive/My Drive/taggedRoofs/TestSet/7...
# 9      0.930448    0.0695521  /content/gdrive/My Drive/taggedRoofs/TestSet/7...
# 10     0.749136     0.250864  /content/gdrive/My Drive/taggedRoofs/TestSet/5...
# ...

# %%
fullTif = r'/([^/]+)$'

re.search(pat, '/content/gdrive/My Drive/taggedRoofs/b_527.tif').group(0)
# Out:
# '/b_527.tif'

# %%
df.to_csv('testSetPreds.csv')
os.getcwd()
# Out:
# '/content/gdrive/My Drive/taggedRoofs'
